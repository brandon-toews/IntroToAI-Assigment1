# %%
import pandas as pd
import numpy as np

# Save data in Pandas dataframe
dataset = pd.read_csv("heart_2020.csv")

# Print how many rows and columns are in dataset
print(dataset.shape)

# Display 1st five entries of dataset
dataset.head()
# Out:
# (319795, 18)
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %%
# Print data types and how many null values are present
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
# Convert object data types to category types
#dataset['HeartDisease'] = dataset['HeartDisease'].astype('category')
#dataset['Smoking'] = dataset['Smoking'].astype('category')
#dataset['AlcoholDrinking'] = dataset['AlcoholDrinking'].astype('category')
#dataset['Stroke'] = dataset['Stroke'].astype('category')
#dataset['DiffWalking'] = dataset['DiffWalking'].astype('category')
#dataset['Sex'] = dataset['Sex'].astype('category')
dataset['Race'] = dataset['Race'].astype('category')
#dataset['Diabetic'] = dataset['Diabetic'].astype('category')
dataset['PhysicalActivity'] = dataset['PhysicalActivity'].astype('category')
dataset['GenHealth'] = dataset['GenHealth'].astype('category')
#dataset['Asthma'] = dataset['Asthma'].astype('category')
#dataset['KidneyDisease'] = dataset['KidneyDisease'].astype('category')
#dataset['SkinCancer'] = dataset['SkinCancer'].astype('category')

dataset['HeartDisease'] = dataset['HeartDisease'].replace(['No'], 0).replace(['Yes'], 1)
dataset['Smoking'] = dataset['Smoking'].replace(['No'], 0).replace(['Yes'], 1)
dataset['AlcoholDrinking'] = dataset['AlcoholDrinking'].replace(['No'], 0).replace(['Yes'], 1)
dataset['Stroke'] = dataset['Stroke'].replace(['No'], 0).replace(['Yes'], 1)
dataset['DiffWalking'] = dataset['DiffWalking'].replace(['No'], 0).replace(['Yes'], 1)
dataset['Sex'] = dataset['Sex'].replace(['Female'], 0).replace(['Male'], 1)
dataset['Diabetic'] = dataset['Diabetic'].replace(['No'], 0).replace(['Yes'], 2).replace(['No, borderline diabetes'], 1).replace(['Yes "("during pregnancy")""'], 3)
dataset['PhysicalActivity'] = dataset['PhysicalActivity'].replace(['No'], 0).replace(['Yes'], 1)
dataset['Asthma'] = dataset['Asthma'].replace(['No'], 0).replace(['Yes'], 1)
dataset['KidneyDisease'] = dataset['KidneyDisease'].replace(['No'], 0).replace(['Yes'], 1)
dataset['SkinCancer'] = dataset['SkinCancer'].replace(['No'], 0).replace(['Yes'], 1)
#dataset['Smoking'] = dataset['Smoking'].replace(['Yes'], 1)

# Convert float data types to integer types
dataset['PhysicalHealth'] = dataset['PhysicalHealth'].apply(int)
dataset['MentalHealth'] = dataset['MentalHealth'].apply(int)
dataset['SleepTime'] = dataset['SleepTime'].apply(int)
#dataset['Diabetic'] = dataset['Diabetic'].apply(int)

# Replace age ranges with a median number
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['18-24'], 21)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['25-29'], 27)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['30-34'], 32)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['35-39'], 37)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['40-44'], 42)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['45-49'], 47)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['50-54'], 52)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['55-59'], 57)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['60-64'], 62)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['65-69'], 67)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['70-74'], 72)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['75-79'], 77)
dataset['AgeCategory'] = dataset['AgeCategory'].replace(['80 or older'], 82)

# Display 1st five entries of dataset showing cleaned data
dataset.head(50)
# Out:
#     HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              0  16.60        1                0       0               3
# 1              0  20.34        0                0       1               0
# 2              0  26.58        1                0       0              20
# 3              0  24.21        0                0       0               0
# 4              0  23.71        0                0       0              28
# 5              1  28.87        1                0       0               6
# 6              0  21.63        0                0       0              15
# 7              0  31.64        1                0       0               5
# 8              0  26.45        0                0       0               0
# 9              0  40.69        0                0       0               0
# 10             1  34.30        1                0       0              30
# 11             0  28.71        1                0       0               0
# ...

# %%
# Print new data types and how many null values are present
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  int64
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  int64
#  3   AlcoholDrinking   319795 non-null  int64
#  4   Stroke            319795 non-null  int64
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DiffWalking       319795 non-null  int64
#  8   Sex               319795 non-null  int64
#  9   AgeCategory       319795 non-null  int64
#  10  Race              319795 non-null  category
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  category
#  13  GenHealth         319795 non-null  category
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#  Initializing data for explorations
#x1 = dataset['PhysicalHealth']
#x2 = dataset['MentalHealth']
#x3 = dataset['AgeCategory']
#x4 = dataset['SleepTime']
#y = dataset['BMI']

#plt.bar(dataset['Diabetic'], y)

#plt.style.use('ggplot')
#plt.figure(figsize=(8,6))
#sns.regplot(x = x1, y = x2)
#plt.show()

#sns.lmplot(x='PhysicalHealth', y='BMI', data=dataset,
#          fit_reg=False,
#          hue='HeartDisease',
#          legend=True,
#          palette="Set1", height=6)

sns.pairplot(dataset, kind= 'scatter', hue= 'GenHealth')
plt.show()

# %%
sns.pairplot(dataset, kind= 'scatter', hue= 'Diabetic')
plt.show()

# %%
sns.pairplot(dataset, kind= 'kde', hue= 'HeartDisease')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/s7/102gqb_s7v51nwr7m5mv445h0000gn/T/ipykernel_49541/1428311708.py in <module>
# ----> 1 sns.pairplot(dataset, kind= 'kde', hue= 'HeartDisease')
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
sns.pairplot(dataset, kind= 'hist', hue= 'HeartDisease')
plt.show()

# %%
sns.pairplot(dataset, kind= 'reg', hue= 'HeartDisease')
plt.show()
