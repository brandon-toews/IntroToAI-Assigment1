# %%
import requests
import pandas as pd
import numpy as np

dataset = pd.read_csv("heart_2020_cleaned.csv")
print(dataset.shape)
dataset.head(40)
# Out:
# (319795, 18)
#    HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0            No  16.60     Yes              No     No             3.0
# 1            No  20.34      No              No    Yes             0.0
# 2            No  26.58     Yes              No     No            20.0
# 3            No  24.21      No              No     No             0.0
# 4            No  23.71      No              No     No            28.0
# 5           Yes  28.87     Yes              No     No             6.0
# 6            No  21.63      No              No     No            15.0
# 7            No  31.64     Yes              No     No             5.0
# 8            No  26.45      No              No     No             0.0
# 9            No  40.69      No              No     No             0.0
# 10          Yes  34.30     Yes              No     No            30.0
# 11           No  28.71     Yes              No     No             0.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
len(dataset)
# Out:
# 319795

# %%
for index, row in dataset.iterrows():
    if row['AgeCategory'][0:2] == '18':
        row['AgeCategory'] = '21'
    elif row['AgeCategory'][0:2] == '25':
        row['AgeCategory'] = '27'
    elif row['AgeCategory'][0:2] == '30':
        row['AgeCategory'] = '32'
    elif row['AgeCategory'][0:2] == '35':
        row['AgeCategory'] = '37'
    elif row['AgeCategory'][0:2] == '40':
        row['AgeCategory'] = '42'
    elif row['AgeCategory'][0:2] == '45':
        row['AgeCategory'] = '47'
    elif row['AgeCategory'][0:2] == '50':
        row['AgeCategory'] = '52'
    elif row['AgeCategory'][0:2] == '55':
        row['AgeCategory'] = '57'
    elif row['AgeCategory'][0:2] == '60':
        row['AgeCategory'] = '62'
    elif row['AgeCategory'][0:2] == '65':
        row['AgeCategory'] = '67'
    elif row['AgeCategory'][0:2] == '70':
        row['AgeCategory'] = '72'
    elif row['AgeCategory'][0:2] == '75':
        row['AgeCategory'] = '77'
    elif row['AgeCategory'][0:2] == '80':
        row['AgeCategory'] = '80'
    
dataset['AgeCategory'].head(20)
    
#dataset['AgeCategory'] = dataset['AgeCategory'].astype(int)
#dataset.loc[0, 'AgeCategory'][0:2]
# Out:
# 0           55-59
# 1     80 or older
# 2           65-69
# 3           75-79
# 4           40-44
# 5           75-79
# 6           70-74
# 7     80 or older
# 8     80 or older
# 9           65-69
# 10          60-64
# 11          55-59
# 12          75-79
# 13    80 or older
# 14          60-64
# 15          50-54
# 16          70-74
# 17          70-74
# 18          75-79
# 19    80 or older
# Name: AgeCategory, dtype: object
